# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID     student_name gender  year         school_name  \
# 0               0     Paul Bradley      M     9   Huang High School
# 1               1     Victor Smith      M    12   Huang High School
# 2               2  Kevin Rodriguez      M    12   Huang High School
# 3               3    Richard Scott      M    12   Huang High School
# 4               4       Bonnie Ray      F     9   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F    12  Thomas High School
# 39166       39166        Dawn Bell      F    10  Thomas High School
# 39167       39167   Rebecca Tanner      F     9  Thomas High School
# 39168       39168     Desiree Kidd      F    10  Thomas High School
# 39169       39169  Carolyn Jackson      F    11  Thomas High School
#
#        reading_score  maths_score  School ID         type  size   budget
# 0                 96           94          0   Government  2917  1910635
# ...

# %% [markdown]
# ## Local Government Area Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average maths score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing maths score (50 or greater)
#
# * Calculate the percentage of students with a passing reading score (50 or greater)
#
# * Calculate the percentage of students who passed maths **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
total_schools = school_data_complete["school_name"].nunique()
#Calculate the total number of students
total_students = school_data_complete["Student ID"].nunique()
#Calculate the total budget
total_budget = school_data["budget"].sum()
#Calculate the average math score and reading score
average_math_score = school_data_complete["maths_score"].mean() 
average_reading_score = school_data_complete["reading_score"].mean()

#Calculate the percentage of students with a passing math score (50 or greater)

limit = 50
mscore = 'maths_score'
# Select column 'C' from the dataframe
column = school_data_complete[mscore]
# Get count of values greater than 50 in the column 'math_score'
count = column[column > limit].count()
math_passing = count / total_students *100


#Calculate the percentage of students with a passing reading score (50 or greater)

limit = 50
rscore = 'reading_score'
# Select column 'C' from the dataframe
column = school_data_complete[rscore]
# Get count of values greater than 50 in the column 'math_score'
count = column[column > limit].count()
read_passing = count / total_students *100

# %%
#Calculate the percentage of students who passed math and reading (% Overall Passing)
# df.loc[(df['team'] == 'A') & (df['conference'] == 'East'), 'points'].sum()
df = school_data_complete
overall_passing_rate = df.loc[(df['maths_score'] > limit) & (df['reading_score'] > limit), "Student ID"].count()/ total_students *100
overall_passing_rate
# Out:
# 69.94383456727087

# %% [markdown]
# ## School Summary

# %%
# Store all calculations into dataframe
district_summary = pd.DataFrame({"Total Schools":[total_schools],
                                 "Total Students":[total_students],
                                 "Total Budget":[total_budget],
                                 "Average Math Score":[average_math_score],
                                 "Average Reading Score":[average_reading_score],
                                 "% Passing Math":[math_passing],
                                 "% Passing Reading":[read_passing],
                                 "% Overall Passing Rate":[overall_passing_rate]})
district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           70.338192
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0              69.980138       84.431963          82.644881
#
#    % Overall Passing Rate
# 0               69.943835

# %% [markdown]
# * Create an overview table that summarises key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed maths **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Create an overview table that summarizes key metrics about each school
# School Name
grouped_school_df = school_data_complete.groupby(["school_name"])
# School Type
schoolType = grouped_school_df["type"].first()
# Total Students
totalStudents = grouped_school_df["Student ID"].count()
# Total School Budget
totalSchoolBudget = grouped_school_df["budget"].first()
# Per Student Budget
perStudentBudget = totalSchoolBudget / totalStudents
# Average Math Score
averageMathScore = grouped_school_df["maths_score"].mean()
# Average Reading Score
averageReadingScore = grouped_school_df["reading_score"].mean()
# % Passing Math
passingMath = school_data_complete[school_data_complete["maths_score"] >= 70].groupby(["school_name"])["maths_score"].count()
percentagePassingMath = passingMath / totalStudents * 100
# % Passing Reading
passingRead = school_data_complete[school_data_complete["reading_score"] >= 70].groupby(["school_name"])["reading_score"].count()
percentagePassingReading = passingRead / totalStudents * 100
# Overall Passing Rate (Average of the above two)
percentageOverallPassingRate = (percentagePassingMath + percentagePassingReading) / 2


# Create a dataframe to hold the above results
school_summary_df = pd.DataFrame({"School Type": schoolType,
      "Total Students": totalStudents,
      "Total School Budget": totalSchoolBudget,
      "Per Student Budget": perStudentBudget,
      "Average Math Score": averageMathScore,
      "Average Reading Score": averageReadingScore,
      "% Passing Math": percentagePassingMath,
      "% Passing Reading": percentagePassingReading,
      "% Overall Passing Rate": percentageOverallPassingRate})
school_summary_df
# Out:
#                        School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School      Government            4976              3124928
# Cabrera High School    Independent            1858              1081356
# Figueroa High School    Government            2949              1884411
# Ford High School        Government            2739              1763916
# Griffin High School    Independent            1468               917500
# Hernandez High School   Government            4635              3022020
# Holden High School     Independent             427               248087
# Huang High School       Government            2917              1910635
# Johnson High School     Government            4761              3094650
# Pena High School       Independent             962               585858
# Rodriguez High School   Government            3999              2547363
# Shelton High School    Independent            1761              1056600
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
#Sort and display the top five performing schools by % overall passing.
school_summary_df = school_summary_df.sort_values(["% Overall Passing Rate"], ascending=False)
school_summary_df.head(5)
# Out:
#                        School Type  Total Students  Total School Budget  \
# school_name
# Holden High School     Independent             427               248087
# Pena High School       Independent             962               585858
# Griffin High School    Independent            1468               917500
# Bailey High School      Government            4976              3124928
# Rodriguez High School   Government            3999              2547363
#
#                        Per Student Budget  Average Math Score  \
# school_name
# Holden High School                  581.0           72.583138
# Pena High School                    609.0           72.088358
# Griffin High School                 625.0           71.788147
# Bailey High School                  628.0           72.352894
# Rodriguez High School               637.0           72.047762
#
#                        Average Reading Score  % Passing Math  \
# school_name
# ...

# %%
# Store all calculations into dataframe
# Out:
#                        School Type  Total Students Total School Budget  \
# Griffin High School    Independent            1468         $917,500.00
# Cabrera High School    Independent            1858       $1,081,356.00
# Bailey High School      Government            4976       $3,124,928.00
# Wright High School     Independent            1800       $1,049,400.00
# Rodriguez High School   Government            3999       $2,547,363.00
#
#                       Per Student Budget  Average Maths Score  \
# Griffin High School              $625.00            71.788147
# Cabrera High School              $582.00            71.657158
# Bailey High School               $628.00            72.352894
# Wright High School               $583.00            72.047222
# Rodriguez High School            $637.00            72.047762
#
#                        Average Reading Score  % Passing Maths  \
# Griffin High School                71.245232        91.212534
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
school_summary_df = school_summary_df.sort_values(["% Overall Passing Rate"], ascending=True)
school_summary_df.head(5)
# Out:
#                        School Type  Total Students  Total School Budget  \
# school_name
# Figueroa High School    Government            2949              1884411
# Johnson High School     Government            4761              3094650
# Wilson High School     Independent            2283              1319574
# Huang High School       Government            2917              1910635
# Hernandez High School   Government            4635              3022020
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Figueroa High School            $630-645           68.698542
# Johnson High School             $645-680           68.843100
# Wilson High School                 <$585           69.170828
# Huang High School               $645-680           68.935207
# Hernandez High School           $645-680           68.874865
#
#                        Average Reading Score  % Passing Math  \
# school_name
# ...

# %% [markdown]
# ## Maths Scores by Year

# %% [markdown]
# * Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#
#   * Create a pandas series for each year. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#year9_ds = school_data_complete.loc[school_data_complete["year"] == 9].groupby(["school_name"])["maths_score"].mean()

year_ds = school_data_complete.loc[school_data_complete["year"] > 8].groupby(["school_name","year"])["maths_score"].mean()

#Create a pandas series for each year. Hint: use a conditional statement.
#Group each series by school
year9_ds = school_data_complete.loc[school_data_complete["year"] == 9].groupby(["school_name"])["maths_score"].mean()
year10_ds = school_data_complete.loc[school_data_complete["year"] == 10].groupby(["school_name"])["maths_score"].mean()
year11_ds = school_data_complete.loc[school_data_complete["year"] == 11].groupby(["school_name"])["maths_score"].mean()
year12_ds = school_data_complete.loc[school_data_complete["year"] == 12].groupby(["school_name"])["maths_score"].mean()

#Combine the series into a dataframe
year_summary_df = pd.DataFrame({9: year9_ds,
      10: year10_ds,
      11: year11_ds,
      12: year12_ds})

year_summary_df[[9, 10, 11, 12]]


#Optional: give the displayed data cleaner formatting
# Out:
#                               9          10         11         12
# school_name
# Bailey High School     72.493827  71.897498  72.374900  72.675097
# Cabrera High School    72.321970  72.437768  71.008299  70.604712
# Figueroa High School   68.477804  68.331586  68.811001  69.325282
# Ford High School       69.021609  69.387006  69.248862  68.617811
# Griffin High School    72.789731  71.093596  71.692521  71.469178
# Hernandez High School  68.586831  68.867156  69.154412  68.985075
# Holden High School     70.543307  75.105263  71.640777  73.409639
# Huang High School      69.081754  68.533246  69.431345  68.639316
# Johnson High School    69.469286  67.990220  68.637730  69.287393
# Pena High School       71.996364  72.396000  72.523438  71.187845
# Rodriguez High School  71.940722  71.779808  72.364811  72.154626
# Shelton High School    72.932075  72.506696  70.097087  72.331536
# Thomas High School     69.234273  70.057007  69.657831  69.369822
# ...

# %% [markdown]
# ## Reading Score by Year

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#Perform the same operations as above for reading scores
year_ds = school_data_complete.loc[school_data_complete["year"] > 8].groupby(["school_name","year"])["reading_score"].mean()

#Create a pandas series for each year. Hint: use a conditional statement.
#Group each series by school
year9_ds = school_data_complete.loc[school_data_complete["year"] == 9].groupby(["school_name"])["reading_score"].mean()
year10_ds = school_data_complete.loc[school_data_complete["year"] == 10].groupby(["school_name"])["reading_score"].mean()
year11_ds = school_data_complete.loc[school_data_complete["year"] == 11].groupby(["school_name"])["reading_score"].mean()
year12_ds = school_data_complete.loc[school_data_complete["year"] == 12].groupby(["school_name"])["reading_score"].mean()

#Combine the series into a dataframe
year_summary_df = pd.DataFrame({9: year9_ds,
      10: year10_ds,
      11: year11_ds,
      12: year12_ds})

year_summary_df[[9, 10, 11, 12]]
# Out:
#                               9          10         11         12
# school_name
# Bailey High School     70.901920  70.848265  70.317346  72.195525
# Cabrera High School    71.172348  71.328326  71.201245  71.856021
# Figueroa High School   70.261682  67.677588  69.152327  69.082126
# Ford High School       69.615846  68.988701  70.735964  68.849722
# Griffin High School    72.026895  70.746305  72.385042  69.434932
# Hernandez High School  68.477569  70.621842  68.418199  69.244136
# Holden High School     71.598425  71.096491  73.310680  70.481928
# Huang High School      68.670616  69.516297  68.740638  68.671795
# Johnson High School    68.719286  69.295029  69.969115  67.992521
# Pena High School       70.949091  72.324000  71.703125  71.513812
# Rodriguez High School  70.902921  70.137500  71.424453  71.414449
# Shelton High School    70.715094  69.879464  71.150485  69.070081
# Thomas High School     69.672451  69.741093  70.749398  68.730769
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# # * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). 
# Sample bins. Feel free to create your own bins.
bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

#create a group based off the bins
school_summary_df["average spending ranges"] = pd.cut(school_summary_df["Per Student Budget"],bins, labels=group_names, include_lowest=True)
df = school_summary_df
df

#create a group based off the bins
df = df.groupby("average spending ranges")
df.max()
# Out:
#                          School Type  Total Students  Total School Budget  \
# average spending ranges
# <$585                    Independent            2283              1319574
# $585-615                 Independent            1761              1056600
# $615-645                 Independent            4976              3124928
# $645-675                  Government            4761              3094650
#
#                          Per Student Budget  Average Math Score  \
# average spending ranges
# <$585                                 583.0           72.583138
# $585-615                              609.0           72.088358
# $615-645                              644.0           72.352894
# $645-675                              655.0           68.935207
#
#                          Average Reading Score  % Passing Math  \
# average spending ranges
# <$585                                71.660422       57.142857
# $585-615                             71.613306       55.405405
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
#Scores by School Size
bins = [0, 1000, 2000, 5000]
group_names = ["Small<1000", "Medium 1000-2000", "large 2000 - 5000"]

#create a group based off the bins
school_summary_df["school size ranges"] = pd.cut(school_summary_df["Total Students"],bins, labels=group_names, include_lowest=True)
df = school_summary_df
df

#create a group based off the bins
df = df.groupby("school size ranges")
df.max()
# Out:
#                     School Type  Total Students  Total School Budget  \
# school size ranges
# Small<1000          Independent             962               585858
# Medium 1000-2000    Independent            1858              1081356
# large 2000 - 5000   Independent            4976              3124928
#
#                     Per Student Budget  Average Math Score  \
# school size ranges
# Small<1000                       609.0           72.583138
# Medium 1000-2000                 638.0           72.047222
# large 2000 - 5000                655.0           72.352894
#
#                     Average Reading Score  % Passing Math  % Passing Reading  \
# school size ranges
# Small<1000                      71.660422       57.142857          55.503513
# Medium 1000-2000                71.359526       54.968768          54.155313
# large 2000 - 5000               71.008842       55.225080          52.788197
#
#                     % Overall Passing Rate average spending ranges
# ...

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
#create a group based off the bins
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9428\1742302324.py in <module>
#       1 #create a group based off the bins
# ----> 2 df = df.groupby("School Type")
#       3 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'
